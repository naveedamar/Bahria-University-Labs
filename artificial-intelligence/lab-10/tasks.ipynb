# %%
#simple chatbot
import requests
import json

#for api call from .env file
from dotenv import load_dotenv
import os
load_dotenv()
api_key = os.getenv("OPENROUTER_API_KEY")

def get_openrouter_response(prompt):
    url = "https://openrouter.ai/api/v1/chat/completions"

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json",
        "HTTP-Referer": "http://localhost:3000",
        "X-Title": "My Local Script",
    }

    data = {
        "model": "baidu/cobuddy:free",
        "messages": [
            {"role": "user", "content": prompt}
        ]
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        result = response.json()
        return result['choices'][0]['message']['content']
    else:
        return f"Error: {response.status_code} - {response.text}"

# Usage
while True:
    prompt = input("You: ")

    if prompt.lower() == "no":
        break

    output = get_openrouter_response(prompt)
    print("Bot:", output)
# Out:
# Bot: I'm an AI assistant made by Anthropic. I'm designed to be helpful, honest, and straightforward. What would you like to know or discuss?
# Bot: I can help with a wide range of tasks, including:
#
# **Writing & Communication**
# - Essays, emails, articles, resumes, cover letters
# - Editing, proofreading, and feedback
#
# **Learning & Research**
# - Explaining concepts across many subjects
# - Summarizing or analyzing texts
# - Answering questions on science, history, math, and more
#
# **Problem-Solving**
# - Math, logic, and reasoning
# - Coding and debugging
# - Decision-making and planning
#
# **Creative Work**
# - Stories, poems, brainstorming ideas
# - Worldbuilding, character development
#
# **Everyday Tasks**
# - Recipes, travel suggestions, recommendations
# - Drafting messages or plans
# - Organizing information
#
# **Analysis**
# - Interpreting data or arguments
# - Comparing options
# - Breaking down complex topics
#
# Is there something specific you'd like help with?
