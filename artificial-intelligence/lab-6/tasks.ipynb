# %%
import random

POP_SIZE = 10
GENS = 35
MUTATION_RATE = 0.1
GENES_PER_CHROMO = 4

def fitness_function(chromosome):

    x, y, z, w = chromosome
    return (x * (3*y) * (5*z) * (9*w)) / 35

def create_individual():
    return [random.randint(0, 1) for _ in range(GENES_PER_CHROMO)]

def mutate(chromosome):
    for i in range(len(chromosome)):
        if random.random() < MUTATION_RATE:
            chromosome[i] = 1 - chromosome[i]
    return chromosome

def crossover(parent1, parent2):
    point = random.randint(1, GENES_PER_CHROMO - 1)
    child1 = parent1[:point] + parent2[point:]
    child2 = parent2[:point] + parent1[point:]
    return child1, child2

population = [create_individual() for _ in range(POP_SIZE)]

print(f"{'Gen':<5} | {'Best Fitness':<12} | {'Avg Fitness':<12} | {'Poor Fitness':<12} | {'Best Individual'}")
print("-" * 75)

for gen in range(1, GENS + 1):
    fitness_scores = [fitness_function(ind) for ind in population]

    best_fit = max(fitness_scores)
    poor_fit = min(fitness_scores)
    avg_fit = sum(fitness_scores) / POP_SIZE
    best_ind = population[fitness_scores.index(best_fit)]

    print(f"{gen:<5} | {best_fit:<12.4f} | {avg_fit:<12.4f} | {poor_fit:<12.4f} | {best_ind}")

    new_population = []
    for _ in range(POP_SIZE // 2):
        parents = random.sample(population, 4)
        parents.sort(key=lambda ind: fitness_function(ind), reverse=True)
        p1, p2 = parents[0], parents[1]

        c1, c2 = crossover(p1, p2)

        new_population.append(mutate(c1))
        new_population.append(mutate(c2))

    population = new_population
# Out:
# Gen   | Best Fitness | Avg Fitness  | Poor Fitness | Best Individual
# ---------------------------------------------------------------------------
# 1     | 3.8571       | 0.3857       | 0.0000       | [1, 1, 1, 1]
# 2     | 0.0000       | 0.0000       | 0.0000       | [1, 0, 0, 1]
# 3     | 0.0000       | 0.0000       | 0.0000       | [0, 1, 0, 1]
# 4     | 0.0000       | 0.0000       | 0.0000       | [0, 1, 0, 1]
# 5     | 0.0000       | 0.0000       | 0.0000       | [1, 0, 1, 1]
# 6     | 0.0000       | 0.0000       | 0.0000       | [0, 0, 1, 0]
# 7     | 0.0000       | 0.0000       | 0.0000       | [1, 1, 0, 1]
# 8     | 0.0000       | 0.0000       | 0.0000       | [1, 1, 0, 0]
# 9     | 0.0000       | 0.0000       | 0.0000       | [1, 0, 1, 1]
# 10    | 0.0000       | 0.0000       | 0.0000       | [1, 1, 1, 0]
# 11    | 3.8571       | 1.5429       | 0.0000       | [1, 1, 1, 1]
# 12    | 3.8571       | 2.7000       | 0.0000       | [1, 1, 1, 1]
# 13    | 3.8571       | 2.3143       | 0.0000       | [1, 1, 1, 1]
# 14    | 3.8571       | 0.7714       | 0.0000       | [1, 1, 1, 1]
# 15    | 3.8571       | 0.7714       | 0.0000       | [1, 1, 1, 1]
# 16    | 3.8571       | 1.5429       | 0.0000       | [1, 1, 1, 1]
# 17    | 3.8571       | 1.9286       | 0.0000       | [1, 1, 1, 1]
# 18    | 3.8571       | 2.7000       | 0.0000       | [1, 1, 1, 1]
# 19    | 3.8571       | 1.5429       | 0.0000       | [1, 1, 1, 1]
# 20    | 3.8571       | 1.9286       | 0.0000       | [1, 1, 1, 1]
# 21    | 3.8571       | 1.5429       | 0.0000       | [1, 1, 1, 1]
# 22    | 3.8571       | 2.7000       | 0.0000       | [1, 1, 1, 1]
# 23    | 3.8571       | 2.7000       | 0.0000       | [1, 1, 1, 1]
# 24    | 3.8571       | 3.4714       | 0.0000       | [1, 1, 1, 1]
# 25    | 3.8571       | 3.0857       | 0.0000       | [1, 1, 1, 1]
# 26    | 3.8571       | 3.0857       | 0.0000       | [1, 1, 1, 1]
# 27    | 3.8571       | 3.0857       | 0.0000       | [1, 1, 1, 1]
# 28    | 3.8571       | 2.3143       | 0.0000       | [1, 1, 1, 1]
# 29    | 3.8571       | 3.0857       | 0.0000       | [1, 1, 1, 1]
# 30    | 3.8571       | 2.3143       | 0.0000       | [1, 1, 1, 1]
# 31    | 3.8571       | 2.3143       | 0.0000       | [1, 1, 1, 1]
# 32    | 3.8571       | 2.3143       | 0.0000       | [1, 1, 1, 1]
# 33    | 3.8571       | 1.9286       | 0.0000       | [1, 1, 1, 1]
# 34    | 3.8571       | 1.9286       | 0.0000       | [1, 1, 1, 1]
# 35    | 3.8571       | 1.5429       | 0.0000       | [1, 1, 1, 1]
