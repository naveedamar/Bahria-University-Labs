# %%
#check
print("lab 3")
# Out:
# lab 3

# %%
#loops
no_of_labs = 16
for lab in range(1, no_of_labs):
    print("Naveed: present in lab ", lab)
# Out:
# Naveed: present in lab  1
# Naveed: present in lab  2
# Naveed: present in lab  3
# Naveed: present in lab  4
# Naveed: present in lab  5
# Naveed: present in lab  6
# Naveed: present in lab  7
# Naveed: present in lab  8
# Naveed: present in lab  9
# Naveed: present in lab  10
# Naveed: present in lab  11
# Naveed: present in lab  12
# Naveed: present in lab  13
# Naveed: present in lab  14
# Naveed: present in lab  15
# Naveed: present in lab  16
# Naveed: present in lab  17

# %%
semester = 5
for sem_cleared in range(1, semester + 1):
    print("Semester: ", sem_cleared)
# Out:
# Semester:  1
# Semester:  2
# Semester:  3
# Semester:  4
# Semester:  5

# %%
labs: list = ["lab 1", "lab 2", "lab 3", "lab 4"]
for lab in labs:
    print(lab)
# Out:
# lab 1
# lab 2
# lab 3
# lab 4

# %%
lab_set: set = (1, 2, 3, 4, 12, 1)
print(lab_set)
# Out:
# (1, 2, 3, 4, 12, 1)

# %%
students = {
    "Naveed": "038",
    "Hadi": "035",
    "Ali": "036",
    "Sara": "037",
}
print(students)

print("\n")

for student in students:
    print("Student: ", student)
    print("Enrollment: ", students[student])
# Out:
# {'Naveed': '038', 'Hadi': '035', 'Ali': '036', 'Sara': '037'}
#
#
# Student:  Naveed
# Enrollment:  038
# Student:  Hadi
# Enrollment:  035
# Student:  Ali
# Enrollment:  036
# Student:  Sara
# Enrollment:  037

# %%
my_id = 38
std_id = input("Enter your ID: ")
if std_id == my_id:
    print("Hello Naveed !")
elif std_id == 35:
    print("Hello Hadi !")
else:
    print("Hello Student !")
# Out:
# Hello Student !

# %%
right_no = 5
while True:
    guess = int(input("Guess: "))
    if guess == right_no:
        print("Your guess is right!")
        break
    elif guess < right_no:
        print("Your guess is too low!")
    else:
        print("Your guess is too high!")
# Out:
# Your guess is too low!
# Your guess is too high!
# Your guess is right!
