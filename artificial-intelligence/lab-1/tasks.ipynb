# %%
# Q1: Salary Calculation
# Employee Details
employee_name = "Naveed Amar"
basic_salary = 50000
allowance = 15000
deduction = 5000

gross_salary = basic_salary + allowance
net_salary = gross_salary - deduction

print("--- Employee Salary Details ---")
print(f"Employee Name: {employee_name}")
print(f"Basic Salary:  {basic_salary}")
print(f"Allowance:     {allowance}")
print(f"Deduction:     {deduction}")
print("-" * 30)
print(f"Gross Salary:  {gross_salary}")
print(f"Net Salary:    {net_salary}")
print("-" * 30)
# Out:
# --- Employee Salary Details ---
# Employee Name: Naveed Amar
# Basic Salary:  50000
# Allowance:     15000
# Deduction:     5000
# ------------------------------
# Gross Salary:  65000
# Net Salary:    60000
# ------------------------------

# %%
# Q2:  Movie Ticket Details
movie_name = "Inception"
holder_name = "Naveed"
original_price = 1200
discount_rate = 0.20

discount_amount = original_price * discount_rate
discounted_price = original_price - discount_amount

print("--- Movie Ticket Invoice ---")
print(f"Movie Name:            {movie_name}")
print(f"Ticket Holder:         {holder_name}")
print(f"Original Ticket Price: {original_price}")
print(f"Discounted Price:      {discounted_price}")
print("----------------------------")
